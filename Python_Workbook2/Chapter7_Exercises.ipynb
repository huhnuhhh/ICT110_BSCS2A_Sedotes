# %% [markdown]
# # CHAPTER 7

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_name = input ("Please enter the file name: ")

try:
  with open (file_name, 'r') as file:
    for line in file:
      print(line.upper(), end = '')
except FileNotFoundError:
  print("File not found!")
except Exception as e:
  print("ERROR!", e)
# Out:
# Please enter the file name: /content/drive/MyDrive/Workbook2_NOTES/Workbook2_Chapter7.txt
# HANNAH SEDOTES BSCS 2-A

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
file_name = open ('/content/drive/MyDrive/ColabNotebooks/Python_Workbook2/Workbook2_NOTES/Workbook2_Chapter7.txt')
text = file_name.read()
print(len(text))
# Out:
# 24

# %% [markdown]
# ## CHALLENGE
#
# from [PEW] E8-2

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %%
X-DSPAM-Confidence: 0.8475
# Out:
#   File "<ipython-input-11-8a7492c5849f>", line 1
#     X-DSPAM-Confidence: 0.8475
#     ^
# SyntaxError: illegal target for annotation

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %%
file_name = input("Enter the file name: ")

try:
    with open(file_name, 'r') as file:
        spam_confidences = [float(line.split(': ')[1]) for line in file if line.startswith('X-DSPAM-Confidence:')]

    if spam_confidences:
        average_spam_confidence = sum(spam_confidences) / len(spam_confidences)
        print("Average spam confidence:", average_spam_confidence)
    else:
        print("No lines starting with 'X-DSPAM-Confidence:' were found in the file.")

except FileNotFoundError:
  print("File not found!", file_name)
except PermissionError:
  print("permission denied", file_name)
except Exception as e:
  print("ERROR!", e)
# Out:
# Enter the file name: /content/drive/MyDrive/ColabNotebooks/Python_Workbook2/Workbook2_NOTES/Chapter7_C.txt
# Average spam confidence: 0.8475
