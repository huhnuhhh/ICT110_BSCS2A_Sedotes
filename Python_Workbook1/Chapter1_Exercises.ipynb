# %% [markdown]
# ##Exercise1

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5780b2d87702> in <cell line: 1>()
# ----> 1 Print('Hello world!')
#
# NameError: name 'Print' is not defined

# %%
print('Hello World')
# Out:
# Hello World

# %%
print'Hello world!')
# Out:
#   File "<ipython-input-3-027e3a63a2c5>", line 1
#     print'Hello world!')
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello world!)

# %%
print('Hello world')
# Out:
# Hello world

# %%
print('Hello world!'')

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ##Exercise2

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# ##Exercise3

# %%
x = 43
x = X + 1
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e86e654f3854> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#
# NameError: name 'X' is not defined

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44
