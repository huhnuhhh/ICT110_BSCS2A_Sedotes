# %% [markdown]
# # Chapter5_Exercise1

# %%
a = 2
b = 2.0
c = a

print(a is c)
print(a == b)
print(a is b)
print(b is c)
print(b == c)
print(a == c)
# Out:
# True
# True
# False
# False
# True
# True

# %% [markdown]
# ## CHALLENGE

# %% [markdown]
# ### Chapter5_Challenge1

# %%
total = 0
count = 0

while True:
  line = input("Enter a number: ")
  if line == 'done':
    break
  try:
    number = float(line)
    total = total + number
    count = count + 1
  except:
    print("Invalid input")
    continue

if count == 0:
  print("No numbers entered.")
else:
  average = total / count
  print(total, count, average)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16.0 3 5.333333333333333

# %% [markdown]
# ### Chapter5_Challenge2

# %%
max = None
min = None
count = 0

while True:
  line = input("Enter a number: ")
  if line == 'done':
    break
  try:
    number = int(line)
    if count == 0:
      max = number
      min = number
    else:
      for num in [number, max, min]:
        if num > max:
          max = num
        if num < min:
          min = num
    count += 1
  except:
    print("Invalid input")
    continue

if count == 0:
  print("No numbers entered.")
else:
  print("Maximum:", max)
  print("Minimum:", min)
# Out:
# Enter a number: 5
# Enter a number: 6
# Enter a number: hannah
# Invalid input
# Enter a number: 4
# Enter a number: 3
# Enter a number: done
# Maximum: 6
# Minimum: 3
