# %%
print("hello world")
# Out:
# hello world

# %%
x = 18
print(x) #displaying a numerical value 6
# Out:
# 18

# %%
x = 10
y = x * 7 # multiplying the content of object x to 7
print(y)
# Out:
# 70

# %%
#The code below will not be executed
#print('Hello World')

# %%
# The text below tries to explain what the code is doing
# Tell python to say "Hello world" in Japanese (romaji)
print('Sekai konnichiwa!')
# Out:
# Sekai konnichiwa!

# %%
#The text below tries to explain what the code is doing
#Tell python to say "Hello world" in Korean (Hangul)
print('Annyeong segye!')
# Out:
# annyeong segye!

# %%
#The code below will only greet in English
print('Hello World!')
#print('Annyeong segye!')
# Out:
# Hello World!

# %% [markdown]
# **Chapter 1: Exercise 1**

# %%
print('Hello world!')
#it had a upper case P, it supposed to be a lower case.
# Out:
# Hello world!

# %%
print('Hello world!')
#no open parethesis
# Out:
# Hello world!

# %%
print('Hello world!')
#no closing single quote
# Out:
# Hello world!

# %%
print('Hello world!')
#multiple single quotation marks
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43
x = x + 1
print(x)
#the upper case X supposed to be a lower case.
# Out:
# 44

# %% [markdown]
# Chapter 2

# %%
print(2)

# %%
type(2)
# Out:
# int

# %%
type('Hello, World!')
# Out:
# str

# %%
type(3.2)
# Out:
# float

# %%
type('17')
# Out:
# str

# %%
type('3.2')
# Out:
# str

# %%
print(1,000,000)
# Out:
# 1 0 0

# %%
class = 2121
# Out:
#   File "<ipython-input-12-5b9b4a4ac3ca>", line 1
#     class = 2121
#           ^
# SyntaxError: invalid syntax

# %%
elif = 'Legolas'
# Out:
#   File "<ipython-input-13-3ec2dce0c046>", line 1
#     elif = 'Legolas'
#     ^
# SyntaxError: invalid syntax

# %%
x = 12.2
print(x)
# Out:
# 12.2

# %%
y = 14
y
# Out:
# 14

# %%
x = 100
x
# Out:
# 100

# %%
x1q3z9ocd = 35.0
x1q3z9afd = 12.50
x1q3p9afd = x1q3z9ocd * x1q3z9afd
print(x1q3p9afd)
# Out:
# 437.5

# %%
a = 35.0
b = 12.50
c = a * b
print(c)
# Out:
# 437.5

# %%
hours = 35.0
rate = 12.50
pay = hours * rate
print(pay)
# Out:
# 437.5

# %%
x = 5

# %%
x = 5

# %%
x = 3.9 *  x  * ( 1  -  x )
x
# Out:
# -78.0

# %%
print(x)
# Out:
# -78.0

# %%
5 + 2
# Out:
# 7

# %%
5 - 2
# Out:
# 3

# %%
5 * 2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %%
x = 1 + 2 * 3 - 4 / 5 ** 6
x
# Out:
# 6.999744

# %%
d = 1 + 4
d

# %%
e = 'hello ' + 'there'
e

# %%
e = 'hello ' + 'there'
e = e + 1

# %%
type(e)

# %%
type(1)

# %%
x = 1 + 2.5
print(x)
print(type(x))

#あ

# %%
string_val = '123'
type(string_val)
# Out:
# str

# %%
print(string_val+1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-b0232912a319> in <cell line: 1>()
# ----> 1 print(string_val+1)
#
# NameError: name 'string_val' is not defined

# %%
int_val = int(string_val)
type(int_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-052de6b228cb> in <cell line: 1>()
# ----> 1 int_val = int(string_val)
#       2 type(int_val)
#
# NameError: name 'string_val' is not defined

# %%
int_val
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-2a145770b2c3> in <cell line: 1>()
# ----> 1 int_val
#
# NameError: name 'int_val' is not defined

# %%
print(int_val+1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d2e13cd1bc1b> in <cell line: 1>()
# ----> 1 print(int_val+1)
#
# NameError: name 'int_val' is not defined

# %%
lotto_jackpot_str = '1,180,622,508'
lotto_jackpot_val = int(lotto_jackpot_str)

#あ
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-c8f2f9b0d0a2> in <cell line: 2>()
#       1 lotto_jackpot_str = '1,180,622,508'
# ----> 2 lotto_jackpot_val = int(lotto_jackpot_str)
#       3
#       4 #あ
#
# ValueError: invalid literal for int() with base 10: '1,180,622,508'

# %%
name = input('Who are you?')
print('Welcome',name)
# Out:
# Who are you?hannah
# Welcome hannah

# %%
bad name = 5
# Out:
#   File "<ipython-input-40-67877bfd5d2a>", line 1
#     bad name = 5
#         ^
# SyntaxError: invalid syntax

# %%
month = 09
# Out:
#   File "<ipython-input-41-e1767aafc583>", line 1
#     month = 09
#             ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
principal = 327.68
interest = principle * rate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b378f79ce02b> in <cell line: 2>()
#       1 principal = 327.68
# ----> 2 interest = principle * rate
#
# NameError: name 'principle' is not defined

# %%
pi = 3.1415
1 / 2*pi
# Out:
# 1.57075

# %%
1/(2*pi)
# Out:
# 0.15915963711602737

# %%
twice_of_pi = 2 * pi
1/twice_of_pi

#あ
# Out:
# 0.15915963711602737

# %% [markdown]
# Chapter 2: Exercise 1

# %%
name = input('Enter your name: ')
print('Hello',name)
# Out:
# Enter your name: hannah
# Hello hannah

# %% [markdown]
# Chapter 2: Exercise 2

# %%
hours = float(input('Enter Hours '))
rate = float(input('Enter Rate '))
pay = hours * rate
print('Pay:', pay)
# Out:
# Enter Hours 35
# Enter Rate 2.745
# Pay: 96.075

# %%
hours = 35
rate = 2.75
pay = hours * rate
print(pay)
# Out:
# 96.25

# %% [markdown]
# Chapter 2: Exercise 3

# %%
width = input("width: ")
height = input("height: ")
# Out:
# width: 17
# height: 12.0

# %%
#width = 17
#height = 12.0

width//2 #The value of this expression is 8. This expression performs integer division on the value of 'width' and '2'.
width/2.0 #The value of this expression is 8.5 and its type is <class 'float'>. This is because we are dividing an integer by a float, which results in a float.
height/3 #The value of this expression is 4.0 and its type is <class 'float'>. This is because we are dividing a float by an integer, which results in a float.
1 + 2 * 5 #The value of this expression is 11 and its type is <class 'int'>. This is because all the operands are integers, so the result is also an integer.
# Out:
# 11

# %% [markdown]
# Chapter 2: Exercise 4

# %%
num = int(input("Enter a number: "))
square = num ** 2
print("The square of", num, "is", square)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# Chapter 2: Challenge

# %%
temp_celsius = float(input("Enter a temperature in Celsius: "))
temp_fahrenheit = (temp_celsius * 9/5) + 32
print("The temperature in Fahrenheit is", temp_fahrenheit)
# Out:
# Enter a temperature in Celsius: 13
# The temperature in Fahrenheit is 55.4

# %% [markdown]
# Chapter 3

# %%
x = 5

# %%
y = 6

# %%
x==5
# Out:
# False

# %%
y==6
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
x != y               # x is not equal to y
# Out:
# True

# %%
inp = input('Europe floor?')
usf = int(inp) + 1
print('US floor', usf)
# Out:
# Europe floor?5
# US floor 6

# %%
string_val = '123'
type(string_val)
# Out:
# str

# %%
badname = 5

# %%
x = 21
if x < 10:
    print('Smaller')
if x > 20:
    print('Bigger')

print('End')
# Out:
# Bigger
# End

# %%
x = 99
if x > 1:
    print('More than one')
    if x < 100:
        print('Less than 100')
print('All done')
# Out:
# More than one
# Less than 100
# All done

# %%
class = 2121
# Out:
#   File "<ipython-input-59-5b9b4a4ac3ca>", line 1
#     class = 2121
#           ^
# SyntaxError: invalid syntax

# %%
x1q3z9ocd = 35.0
x1q3z9afd = 12.50
x1q3p9afd = x1q3z9ocd * x1q3z9afd
print(x1q3p9afd)
# Out:
# 437.5

# %%
a = 35.0
b = 12.50
c = a * b
print(c)
# Out:
# 437.5
